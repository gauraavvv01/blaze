# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.impute import SimpleImputer 
df = pd.read_csv("heart.csv")

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ##  bar graph

# %%
sns.displot(df['Age'])
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Age'],kde = True)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Histogram

# %%
sns.distplot(df['Age'],kde = False , hist = True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_13264\4063583836.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde = False , hist = True)
# <Axes: xlabel='Age'>

# %% [markdown]
# ## rug plot

# %%
sns.distplot(df['Age'],kde = False , hist = False,rug = True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_13264\1074490077.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde = False , hist = False,rug = True)
# <Axes: xlabel='Age'>

# %%
sns.displot(df['Age'], bins = 5)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Age'], bins = 10)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['RestingBP'], kde = True,bins = 10,color = 'green')
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Cholesterol'], kde = True,color = 'green')
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['FastingBS'], kde = True,color = 'green')
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['Oldpeak'], kde = True,color = 'green')
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ###  Categorical pie chart

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind = 'pie')
# Out:
# <Axes: >

# %%
df.groupby('Sex').size().plot(kind = 'pie',autopct = '%.4f')  #decimal place autopct
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie',autopct = '%.4f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie',autopct = '%.4f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie',autopct = '%.4f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie',autopct = '%.4f')
# Out:
# <Axes: >

# %% [markdown]
# ## voiln plot

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: >

# %%
sns.violinplot(y= df['Age'],x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y= df['Age'],x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.violinplot(y= df['RestingBP'],x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(y= df['Cholesterol'],x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# #### heat map correlation

# %%
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
df.corr( numeric_only = True)   #correaltion between columns
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
# more near to 1 better correlated

# %%
# negative correlated one incerease then related column decereases

# %%
sns.heatmap(df.corr(numeric_only = True))
# Out:
# <Axes: >

# %% [markdown]
# ## joint plot - correlations

# %%
sns.jointplot(x ='Age', y = 'MaxHR',data = df)

# %%
sns.jointplot(x ='Age', y = 'Age',data = df)

# %%
sns.jointplot(x ='HeartDisease', y = 'Oldpeak',data = df)

# %%
sns.jointplot(x ='Cholesterol', y = 'Oldpeak',data = df)

# %%
sns.jointplot(x ='Age', y = 'MaxHR',data = df,kind ='hex')

# %%
sns.jointplot(x ='Age', y = 'MaxHR',data = df,kind = 'reg')

# %%
#  age inc maxhr is  decrease

# %%
sns.jointplot(x ='Cholesterol', y = 'FastingBS',data = df,kind = 'reg')

# %%
#  regerssion line

# %%
sns.jointplot(x ='HeartDisease', y = 'MaxHR',data = df,kind = 'reg')

# %% [markdown]
# ## pair plot -correlation

# %%
sns.pairplot(df,kind= 'reg')
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
